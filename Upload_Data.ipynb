# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamaswani/DataScienceAndAI/blob/main/Upload_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Public Link

# %%
# !wget https://support.staffbase.com/hc/en-us/article_attachments/360009197031/username.csv
# Out:
# --2025-08-10 20:52:45--  https://support.staffbase.com/hc/en-us/article_attachments/360009197031/username.csv
# Resolving support.staffbase.com (support.staffbase.com)... 216.198.54.6, 216.198.53.6
# Connecting to support.staffbase.com (support.staffbase.com)|216.198.54.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176 [text/csv]
# Saving to: ‘username.csv’
#
# username.csv        100%[===================>]     176  --.-KB/s    in 0s
#
# 2025-08-10 20:52:46 (48.6 MB/s) - ‘username.csv’ saved [176/176]

# %%
# !ls
# Out:
# sample_data  username.csv

# %%
import pandas as pd
pd.read_csv('username.csv', sep=';').head()
# Out:
#     Username   Identifier First name Last name
# 0   booker12         9012     Rachel    Booker
# 1     grey07         2070      Laura      Grey
# 2  johnson81         4081      Craig   Johnson
# 3  jenkins46         9346       Mary   Jenkins
# 4    smith79         5079      Jamie     Smith

# %% [markdown]
# # Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/Miscellaneous/TransactionHistory.csv', sep=',').head()
# Out:
#    24/12/2024                        VODAFONE LTD DD     -42.03
# 0  21/12/2024  Austin Cleaning 41Wentworth IP83RX BP     -17.00
# 1  21/12/2024          Rob Instructor Poonam Vyas BP     -76.00
# 2  16/12/2024                    HSBC CREDIT CARD DD  -1,741.45
# 3  15/12/2024          Rob Instructor Poonam Vyas BP     -76.00
# 4  11/12/2024              GAVAN B&H Yoga & Lunch BP      34.00
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('24/12/2024').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_16.groupby('VODAFONE LTD DD').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# # Github Link

# %%
# !git clone https://github.com/datablist/sample-csv-files.git
# Out:
# Cloning into 'sample-csv-files'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 42 (delta 18), reused 32 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 19.20 KiB | 2.74 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %% [markdown]
# # Local Drive

# %%
pd.read_csv('customers-10000.csv')
